# %% [markdown]
# # This is a lab on Webscraping
# #### In this lab we go over different webscraping techniques and how to scape a webpage for data

# %%
# !pip install html5lib
# !pip install lxml
# !pip install beautifulSoup4
# !pip install bs4
# Out:
# ...
#      |████████████████████████████████| 112 kB 4.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.5 MB 4.1 MB/s eta 0:00:01
# ...

# %%
import html5lib
import lxml
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %%
# %%html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Page Title</title>
# </head>
# <body>
# <h3><b id='boldest'>Lebron James</b></h3>
# <p> Salary: $ 92,000,000 </p>
# <h3> Stephen Curry</h3>
# <p> Salary: $85,000, 000 </p>
# <h3> Kevin Durant </h3>
# <p> Salary: $73,200, 000</p>
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Page Title</title>
# </head>
# <body>
# <h3><b id='boldest'>Lebron James</b></h3>
# <p> Salary: $ 92,000,000 </p>
# <h3> Stephen Curry</h3>
# <p> Salary: $85,000, 000 </p>
# <h3> Kevin Durant </h3>
# <p> Salary: $73,200, 000</p>
# </body>
# </html>

# %%
#Store the HTML as a string to the variable html
html="<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>Lebron James</b></h3><p>"

# %%
soup = BeautifulSoup(html, 'html5lib')
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# <ipython-input-19-0b070edd802d> in <module>
# ----> 1 soup = BeautifulSoup(html, 'html5lib')
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     244                     "Couldn't find a tree builder with the features you "
#     245                     "requested: %s. Do you need to install a parser library?"
# --> 246                     % ",".join(features))
#     247
#     248         # At this point either we have a TreeBuilder instance in
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: html5lib. Do you need to install a parser library?

# %%
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-df8ea84c4b29> in <module>
# ----> 1 print(soup.prettify())
#
# NameError: name 'soup' is not defined

# %%
tag_object = soup.title
print("tag object:",tag_object)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-b00cffb3479e> in <module>
# ----> 1 tag_object = soup.title
#       2 print("tag object:",tag_object)
#
# NameError: name 'soup' is not defined

# %%
tag_child =tag_object.b
tag_child
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-bded094f0256> in <module>
# ----> 1 tag_child =tag_object.b
#       2 tag_child
#
# NameError: name 'tag_object' is not defined

# %%
parent_tag=tag_child.parent
parent_tag
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-ade891ac9010> in <module>
# ----> 1 parent_tag=tag_child.parent
#       2 parent_tag
#
# NameError: name 'tag_child' is not defined

# %%
sibling_1=tag_object.next_sibling
sibling_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-e47a279fafcf> in <module>
# ----> 1 sibling_1=tag_object.next_sibling
#       2 sibling_1
#
# NameError: name 'tag_object' is not defined

# %%
sibling_2=sibling_1.next_sibling
sibling_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-0c067e03064d> in <module>
# ----> 1 sibling_2=sibling_1.next_sibling
#       2 sibling_2
#
# NameError: name 'sibling_1' is not defined

# %%
sibling_3 = sibling_2.next_sibiling
sibling_3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-d1fc099ebe6e> in <module>
# ----> 1 sibling_3 = sibling_2.next_sibiling
#       2 sibling_3
#
# NameError: name 'sibling_2' is not defined
